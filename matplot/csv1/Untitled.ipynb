# %%
import numpy as np
from matplotlib import pyplot as plt,style
style.use('ggplot')

readFile=np.genfromtxt('reference.csv',delimiter=',')
plt.plot(readFile,marker='o',color='k')
# plt.plot([1,2,3,4,5],[4,5,6,7,8],marker='o',color='k',label='random')

plt.xlabel("X axis")
plt.ylabel("Y axis")

plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.
